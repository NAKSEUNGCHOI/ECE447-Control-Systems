# %% [markdown]
# # HW1 due 5p Fri Oct 15 2021
#
# You are welcome (and encouraged) to work with others, but each individual must submit their own writeup.
#
# You are welcome to use analytical and numerical computational tools; if you do, include the **commented** sourcecode in your submission (e.g. the .ipynb file).
#
# You are welcome to consult websites, textbooks, and other materials; if you do, include a full citation in your writeup (e.g. the .ipynb file).
#
# **Important:** before you do any work in the Colaboratory notebook, click "File -> Save a copy in Drive ..." and rename the file to something memorable.
#
# **Also important:** To produce a .pdf for submission to Canvas, click "File -> Print" (or press Ctrl/Cmd + P), and choose "Save to PDF" or "Microsoft Print to PDF" as your printer.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # 0. [Nakseung Choi]; [He/Him/His]
#
# a. Approximately how many hours did you spend on this assignment?
#   10-15 hours
#
# b. Were there specific problems that took much longer than others?
#   question #3
#
# c. What class meeting(s) did you participate in this week?
#    I participated in all this week.
#
# d. What timezone(s) were you working in this week?
#   Any timezone I could work

# %% [markdown]
# # 1. control systems
#
# ***Purpose:*** apply control systems concepts and terminology in real-world examples and applications.
#
# Read Chapter 1 of the Astrom / Murray v2 textbook [[AMv2]](http://www.cds.caltech.edu/~murray/amwiki/index.php/Second_Edition), and report your solutions to Exercises 1, 2, 3, and 7 from Chapter 1.
#
# 1.1 Perform the following experiment and explain your results: Holding your head still, move one of your hands left and right in front of your face, following it with your eyes. Record how quickly you can move your hand before you begin to lose track of it. Now hold your hand still and shake your head left to right, once again recording how quickly you can move before losing track of your hand.
#
#
# Solution: The experiment shows that it is much easier to track fast when my hand is fixed. The reason is because they have two different feedback systems. When I hold my hand still and move my head left to right, my brain only needs to send signals to move my head to keep track of my fixed hand. However, when I have to keep track of my hand moving left to right with my eyes, it takes more time to process the image in my brain and keep track of the speed of my moving hand at the same time. In addition, my brain has to deal with the movement of my hand as well. So, the process is much harder than the process of the first situation.
#
#
# 1.2 Identify five feedback systems that you encounter in your everyday environment. For each system, identify the sensing mechanism, actuation mechanism and control law. Describe the uncertainty with respect to which the feedback system provides robustness and/or the dynamics that are changed through the use of feedback.
#
# Solution:
#
#
# Washing Machine
#
# Sensing: A machanical sensor reports the size and weight of laundry load.
#
# Computation: The system compares to the desired rotational speed for a particular laundry setting.
#
# Actuation: The electrical motor runs the desired duration and rotational speed.
#
# Effect: It prevents the washing machine from malfunctioning or failure and saves the energy.
#
#
# Air-conditioning
#
# Sensing: A thermal sensor detects the temperature of the room.
#
# Computation: The system compares to the temperature.
#
# Actuation: The air-conditioning generates cooler air.
#
# Effect: A desired temperature is maintained despite other potential heat
#
# sources.
#
#
# Human Locomotion
#
# Sensing: Balance mechanisms and eyes detect the condition of the environment.
#
# Computation: The brain maintains several feedback systems between the current motion, environment, and the condition of the body.
#
# Acutation: Muscles are ordered to move in certain ways.
#
# Effect: It starts to walk in balance regardless of the road condition.
#
#
# Water drinking
#
# Sensing: A body detects the amount of water going into the body.
#
# Computation: The brain compares to the desired amount of water.
#
# Actuation: Hands control the water bottle.
#
# Effect: A desired amount of water can go into the body.
#
# Car Cruise Control
#
# Sensing: A speed control system detects the current speed.
# Computation: The system compares the current speed to the set speed.
# Actuation: A throttle is controled by the actuator.
# Effect: The car continues to travel at the same speed.
#
# 1.3 Balance yourself on one foot with your eyes closed for 15s.
# Using Figure 1.3 as a guide, describe the control system responsible for keeping you from falling down. Note that the “controller” will differ from that in the diagram (unless you are an android reading this in the far future)
#
# Actuator: In human body, a sole, leg, and arms are part of actuators that keep a body balanced.
#
# System: This is the balance mechanisms and systemㄴ in my body.
#
# External Disturbances: These can be wind and the condition of the ground.
#
# Sensors: cochlea, sense of my sole, and neural system can be an example for this.
#
# Noise: This could be the imperfections in the sensors described above.
# It can be devided into two catagories: congenital or acquired difference between humans.
#
# Computer: The human brain processes to generate signals and send it out to correct the balance of the body.
#
# Operator Input: Human's desire to do the action.
#
# Noise: This can be human's feelings and mindset, such as confidence anxiousness, and nervousness. A human who doesn't feel nervous and confident to accomplish this task can change the result.
#
#
# 1.7 earch the web and pick an article in the popular press about a feedback and control system. Describe the feedback system using the terminology given in the article. In particular, identify the control system and describe (a) the underlying process or system being controlled, along with the (b) sensor, (c) actuator and (d) computational element. If the some of the information is not available in the article, indicate this and take a guess at what might have been used.
#
# Tesla's Autopilot
#
# (a) The system that runs Autopilot is called Dojo system.
#
# (b) The sensors used in this system are a forward radar, a forward-looking camera, a high-precion degitally controlled electric assist with braking system, nd 12 long-range ultrasonic sensors placed all around the car.
#
# (c)These sensors described above help the car detect its environment report the data to dojo systems so that it can safely steer, accelerate, and break in most highway situations.
#
# (d) Tesla use FSD chip and Dojo chip to store dojo systems that involve 48 networks that take 70000 GPU hours to train. they output 1,000 distinct predictions at each timestep. For example, in deep neural network, the per-camera network analyzes raw images to perform semantic segmentation, object detection, and monocular depth estimation. The bird-eye-view networks take video from all camera to output the road layout, static infrastructure and 3D objects in the top down view
#
#
# https://www.businessinsider.com/how-teslas-autopilot-works-2016-7#teslas-autopilot-system-is-made-up-of-multiple-sensors-placed-all-around-the-car-these-sensors-help-the-car-understand-its-environment-so-that-it-can-safely-steer-itself-in-most-highway-situations-1
#
# https://www.tesla.com/AI

# %% [markdown]
# # 2. proportional-integral control
#
# This problem considers the following standard negative feedback block diagram.
#
# ![negative feedback block diagram](http://faculty.washington.edu/sburden/447/447-hw1-feedback.png)
#
# ***Purpose:*** you will analyze and synthesize a ***proportional-integral*** controller
# $$ C(s) = k_P + k_I/s \iff u(t) = k_P e(t) + k_I \int_0^t e(\tau) d\tau $$
# for the purpose of ***reference tracking*** (*not* disturbance rejection, which we covered in lecture) in the presence of ***unmodeled dynamics***.
#
# first-order process
# --
#
# First, you will apply the proportional-integral controller to a ***first-order*** process model $P(s) = b / (s + a)$.
#
# a. Determine the transfer function $G_{yr}$; simplify your formula until $G_{yr}$ is a rational function.  (***Note:***  we focused on $G_{yv}$ in lecture, not $G_{yr}$; however, we did derive the general formula for $G_{yr}$, which you can use to solve this problem.)
#
# $$$$
# $$G_{yr} = \frac{b(k_ {p}S+k_ {I})}  {S^{2}+aS+b(k_{p}S+k_ {I})}$$
#
#
# $$$$
# **I'm still trying to get used to the representation of mathematic equations on the collaborative notebook, so I may have made some mistakes.
# Thus, I attached my physical notebook at the end. Please understand.**
# $$$$
#
#
# b. Evaluate $G_{yr}(0)$. What does this value imply about ***asymptotic reference tracking***, i.e. if the reference is constant, $r(t) = r_0$, how does $\lim_{t\rightarrow\infty} y(t)$ relate to $r_0$ (assuming the system is stable so $\lim_{t\rightarrow\infty} y(t)$ always exists)?   (***Note:*** $G_{yr}(0)$ is termed the ***static gain***)
# $$$$
# **From the equation I got above, put 0 into S,**
#
# $$ \frac{bk_ {I}} {bk_ {I}} = 1$$
# $$$$
#
# c. How does $G_{yr}(0)$ change if the process gain increases by $10\%$ (i.e. what happens if you replace $P$ by $1.1\cdot P$) -- in particular, does $G_yr(0)$ change by more or less than $10\%$?  (***Hint:*** you should conclude that feedback reduces the effect of model uncertainty.)
#
# $$1.1*P(s)$$
# $$$$
# $$G_{yr}{(0)} = 1$$
# $$$$
# Even if the process gain increases by 10%, it still gets simplified and becomes 1. Thus, it does not change more or less than 10%. It stays the same.
#
#
# second-order process
# ---
# Now consider the ***second-order*** process model $P(s) = \frac{b}{s^2 + a_1 s + a_2}$.
#
# d. Determine the degree of the numerator and denominator polynomials of $P$ and $C$. (***Hint:*** you need to simplify $C$ until it is a ***rational function***, that is, a ratio of two polynomials.)
#
# Degree of numerator of P(S) $$ 0 $$
#
# Degree of denominator of P(S) $$ 2 $$
#
# Degree of numerator of C(S) $$ 1 $$
#
# Degree of denominator of C(S) $$ 1 $$
#
# e. Determine the degree of the numerator and denominator polynomials of the closed-loop transfer function $G_{yr}$.  (***Hint:*** you need to simplify $G_{yr}$ until it is a ***rational function***, that is, a ratio of two polynomials.)
#
# $$G_{yr} = \frac{P(s)C(s)} {1+P(s)C(s)}$$
# $$$$
# $$= \frac{b(k_ {p}S+k_ {I})}  {S(S^{2}+a_{1}S+a_{2})+b(k_{p}S+k_ {I})}$$
# $$$$
# Degree of numerator $$ 1 $$
#
# Degree of denominator $$ 3 $$
# $$$$
# ***Takeaway:*** the integral term in the proportional-integral controller introduces new dynamics to the system that increases the dynamical complexity (as measured by the degree of the characteristic polynomial of $G_{yr}$) of the closed-loop system.

# %% [markdown]
# # 3. simulation of DE
#
# ***Purpose:*** computationally verify that the solution of a differential equation is a linear combination of the ***homogeneous*** and ***particular*** solutions.
#
# Use this script in the following problems -- it computes a numerical approximation to the solution of the following (DE):
# $$\dot{y} + a y = b u.$$
# (If you're curious about where the script came from, read the explanation that appears after problem (c.) below.)

# %%
import numpy as np
import pylab as plt # pylab == matplotlib.pyplot

# DE parameters
a = 1.
b = 1.

# initial value, final time, timestep
y0 = 1.
t = 20.
dt = 1e-2

# time points -- multiples of dt from 0 to t
T = np.arange(0,t,dt)

# input
def sin(s):
  return b/((s*s)+1)
def cos(s):
  return b*s/((s*s)+1)

y = [y0] # output
y1 = [y0] # output
for s in T[:-1]: # loop through times; exlude final time
  y.append(sin(s)/(s+a)) # DE
y = np.array(y)
for s in T[:-1]: # loop through times; exlude final time
  y1.append(cos(s)/(s+a)) # DE
y1 = np.array(y1)

plt.subplot(2,1,1)
plt.plot(T, y, 'b', label ='y',linewidth=2)
plt.plot(T, y1, 'r', label ='y1',linestyle='--', linewidth=2)
plt.ylabel(r'output ($y$)')
plt.xticks([]) # remove "ticks" on the x-axis
plt.legend()

plt.subplot(2,1,2)
plt.plot(T,y)
plt.plot(T,y1)
plt.ylabel(r'input ($u$)')
plt.xlabel(r'time ($t$)')
plt.tight_layout() # adjusts sizes and locations
plt.legend()

pass
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# a. With $u(s) = 0$, simulate the DE twice:  first with $y_1(0) = 1$ to obtain numerical simulation $\tilde{y}_1$ and second with $y_3(0) = 3$ to obtain numerical simulation $\tilde{y}_3$.  Show that $\tilde{y}_3 = 3 \tilde{y}_1$ by plotting $\tilde{y}_3$ and $3 \tilde{y}_1$ on the same axis using the following code snippet.
#
# ***Note:*** the code snippet below includes informative axis labels and a legend on the plot, and uses different a different line style / width for the second line to distinguish it from the first -- ***all plots you create in this course should have similarly informative labels (and legends, as applicable), and make use of different line styles / widths to distinguish lines.***  Unabeled or otherwise uninterpretable plots will not be graded for credit.

# %%
# code for problem (a.) goes here
# input
u = lambda s: 0
y1_0 = 1
y3_0 = 3
def simulate_y(y0, u, T, dt, a, b):
 y = [y0] # output
 for s in T[:-1]: # loop through times; exlude final time
    y.append(y[-1] + dt * (-a*y[-1] + b*u(s))) # DE
 return y
y1 = simulate_y(y1_0, u, T, dt, a, b)
y3 = simulate_y(y3_0, u, T, dt, a, b)
# Alternative method (less efficient)-- not writing a function but using the code directly instead
# y1 = [y1_0] # output for y1
# for s in T[:-1]: # loop through times; exlude final time
# y1.append(y1[-1] + dt * (-a*y1[-1] + b*u(s))) # DE
 
# y3 = [y3_0] # output for y3
# for s in T[:-1]: # loop through times; exlude final time
# y3.append(y3[-1] + dt * (-a*y3[-1] + b*u(s))) # DE..
y1 = np.array(y1) # convert Python list y1 to NumPy array
y3 = np.array(y3) # convert Python list y1 to NumPy array
# code snippet for plotting in problem (a.)
plt.plot(T, 3*y1, 'r', label=r'$3y_1$') # label this line for inclusion in a legend
plt.plot(T, y3, label=r'$y_3$', linestyle='--', linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend() # adds legend using label's specified in plot(...) commands

pass

# %%
# code snippet for plotting in problem (a.)
y1 = np.array(y1) # convert Python list y1 to NumPy array
plt.plot(T,3*y1,label=r'$y_1$') # label this line for inclusion in a legend
plt.plot(T,y1+y2,label=r'$y_1+y_2$',linestyle='--',linewidth=2) 
plt.plot(T,y3.real,label=r'$y_3$',linestyle='--',linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend() # adds legend using label's specified in plot(...) commands

# %% [markdown]
# b. With $y(0) = 0$, simulate the DE three times:  first with $u_{\sin}(t) = \sin(t)$ to obtain simulation $\tilde{y}_{\sin}$, second with $u_{\cos}(t) = \cos(t)$ to obtain simulation $\tilde{y}_{\cos}$, and third with $u_{\sin+\cos}(t) = \sin(t) + \cos(t)$ to obtain solution $\tilde{y}_{\sin+\cos}$.  Show that $\tilde{y}_{\sin+\cos} = \tilde{y}_{\sin} + \tilde{y}_{\cos}$ by plotting $\tilde{y}_{\sin+\cos}$ and $\tilde{y}_{\sin} + \tilde{y}_{\cos}$ on the same axis.  Vary the line style/width and include a legend as in the previous problem to make it easy to visually distinguish the two lines.

# %%
# code for problem (b.) goes here
#inputs
u_sin = lambda s: np.sin(s)
u_cos = lambda s: np.cos(s)
u_sin_cos = lambda s: np.sin(s) + np.cos(s)
y0 = 0.
y_sin = simulate_y(y0, u_sin, T, dt, a, b)
y_cos = simulate_y(y0, u_cos, T, dt, a, b)
y_sin_cos = simulate_y(y0, u_sin_cos, T, dt, a, b)
y_sin = np.array(y_sin)
y_cos = np.array(y_cos) 
y_sin_cos = np.array(y_sin_cos) 
plt.plot(T, y_sin + y_cos, label=r'$y_{sin} + y_{cos}$')
plt.plot(T, y_sin_cos, label=r'$y_{sin + cos}$', linestyle='--', linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()

pass

# %% [markdown]
# c. Experiment with at least one of the following and describe how the simulation results change.
# * Increase the timestep $\delta t$ to $0.1$, $1$, or larger.
# * Change the value of $a$, keeping the sign the same.
# * Change the sign of $a$, keeping the value the same.

# %%
# code for problem (c.) goes here

dt_1 = 0.1
dt_2 = 1
y0_prob3 = 1.
y_prob3a_1 = simulate_y(y0_prob3, u_sin, T, dt_1, a, b)
y_prob3a_2 = simulate_y(y0_prob3, u_sin, T, dt_2, a, b)
y_prob3a_1 = np.array(y_prob3a_1)
y_prob3a_2 = np.array(y_prob3a_2) 
plt.plot(T, y_prob3a_1, label=r'$dt = 0.1$')
plt.plot(T, y_prob3a_2, label=r'$dt = 1$', linestyle='--', linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
pass

# %%
# code for problem (c.) goes here

a_3b = 3.
y_prob3b = simulate_y(y0_prob3, u, T, dt, a_3b, b)
y_prob3b = np.array(y_prob3b)
plt.plot(T,y_prob3b,label=r'$a = 3.$')
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()

pass

# %% [markdown]
# d. Express $u_1(t) = \sin(t)$ and $u_2(t) = \cos(t)$ as complex exponentials.
#
# $$$$
# $$ cos(t) = \frac{e^{jt}+e^{-jt}} {2}$$
# $$$$
# $$ sin(t) = \frac{e^{jt}-e^{-jt}} {2j}$$

# %% [markdown]
# e. Use the transfer function representation of the model specified by (DE) to determine the system's response to the two inputs in (d.) and create a plot to compare with your results from (b.).
# $$$$
# $$ Y(s)_{sin}= \frac{b} {(s^2+1)(s+a)}$$
# $$$$
# $$ Y(s)_{cos}= \frac{bS} {(s^2+1)(s+a)}$$
# $$$$
# **because we know that a = 1 b = 1.**
# $$$$
# $$ Y(s)_{sin} = \frac{1} {(s^2+1)(s+1)}$$
# $$$$
# $$ Y(s)_{cos} = \frac{s} {(s^2+1)(s+1)}$$
# $$$$
# **Inverse laplace transform for both, we get,**
# $$$$
# $$ y(t)_{sin} = \frac{-cos(t)+sin(t)+e^{-t}} {2}$$
# $$$$
# $$ y(t)_{sin} = \frac{cos(t)+sin(t)-e^{-t}} {2}$$
# $$$$
# **Using two equations above, three plots can be drawn to compare with the results from (b.)**

# %%
y11 = (np.exp(-T) - np.cos(T) + np.sin(T)) / 2 #inverse laplace for transfer function with sin(t)
y22 = (-np.exp(-T) + np.cos(T) + np.sin(T)) / 2 #inverse laplace for transfer function with cos(t)

#plot y11 and y_sin and compare them.
fig1 = plt.figure(1)
plt.plot(T, y11, label=r'$y11$')
plt.plot(T, y_sin, label=r'$y_{sin}$', linestyle = '--',linewidth = 3)
plt.legend()

#plot y22 and y_cos and compare them.
fig2 = plt.figure(2)
plt.plot(T, y22, label=r'$y22$')
plt.plot(T, y_cos, 'r', label=r'$y_{cos}$', linestyle = '--',linewidth = 3)
plt.legend()

#plot y11+y22 and y_sin_cos and compare them.
fig2 = plt.figure(3)
plt.plot(T, y11+y22, label=r'$y11+y22$')
plt.plot(T, y_sin_cos, 'y', label=r'$y_{sin+cos}$', linestyle = '--',linewidth = 3)
plt.legend()

# %% [markdown]
# ***Where did the simulation script come from?*** If you're interested to understand where the script above came from, read the following explanation.
#
# Consider the ***differential equation***
# $$\dot{y} + a y = b u.$$
#
# If the pair of signals $(u,y)$ are a solution to the differential equation from problem (4.), then they approximately solve the ***difference equation***
#
# $$ \frac{1}{\delta t}(y(t + \delta t) - y(t)) + a y(t) \simeq b u(t); $$
#
# this equation can be derived directly from the definition of the time derivative $\dot{y}$ of the signal $y$.  Rearranging this difference equation, we find the approximation
#
# $$ \tilde{y}[t + \delta t] = \tilde{y}[t] + \delta t ( -a \tilde{y}[t] + b u[t] ). $$
#
# This difference equation can be used to approximate solutions to the original differential equation as follows:
# 0. suppose initial value $y(0)$, input $u:\mathbb{R}\rightarrow\mathbb{R}$, final time $t > 0$, and timestep $\delta t > 0$ are given, and set $k = 0$, $\tilde{y}[0] = y(0)$;
# 1. set $\tilde{y}[(k+1)\cdot\delta t] = \tilde{y}[k\cdot\delta t] + \delta t ( -a \tilde{y}[k\cdot\delta t] + b u[k\cdot\delta t] )$;
# 2. set $k = k+1$;
# 3. if $k\cdot\delta t < t$, go back to step (1.), otherwise stop.
#
# The sequence of values $\tilde{y}[k\cdot\delta t]$ for $k\in\mathbb{N}$ approximate the solution $y(k\cdot\delta t)$ of the original differential equation; when we implement this approximation on a computer, we call $\tilde{y}$ a ***numerical simulation*** of $y$.
#
# Translating the algorithm specified by the pseudocode (0.)--(3.) to Python, we obtain the preceding script.
